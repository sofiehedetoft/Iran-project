# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cmcrameri import cm
import os

# %% [markdown]
# # Import datasets from py file

# %%
from data_Iran import ds_AIFS_sfc, ds_ERA5_sfc, ds_AIFS_pl, ds_ERA5_pl
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from data_Iran import ds_AIFS_sfc, ds_ERA5_sfc, ds_AIFS_pl, ds_ERA5_pl
#
# ImportError: cannot import name 'ds_AIFS_sfc' from 'data_Iran' (/Users/sofiehedetoft/Library/CloudStorage/OneDrive-Personligt/KU/Msc Climate Change/Kurser Bern/Seminar in Climatology/Iran-project/data_Iran.py)
